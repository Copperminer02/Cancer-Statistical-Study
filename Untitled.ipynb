# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
ecd_path = Path('ecd1.csv')
ecd_df = pd.read_csv(ecd_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/fm/gprnvv4s0gb6vzrbzyn2ctcc0000gn/T/ipykernel_34243/1256602226.py in <module>
#       1 ecd_path = Path('ecd1.csv')
# ----> 2 ecd_df = pd.read_csv(ecd_path)
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ecd1.csv'

# %%
file_path = Path('LoanStats_2019Q1.csv')
df = pd.read_csv(file_path, skiprows=1)[:-2]
df = df.loc[:, columns].copy()

# %%
ecd_df = pd.read_csv(ecd_path, index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/fm/gprnvv4s0gb6vzrbzyn2ctcc0000gn/T/ipykernel_34243/2412531358.py in <module>
# ----> 1 ecd_df = pd.read_csv(ecd_path, index_col = 0)
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/ecd1.csv'

# %%
ecd_df.head()
# Out:
#             Code  Year  \
# Entity
# Afghanistan  AFG  1990
# Afghanistan  AFG  1991
# Afghanistan  AFG  1992
# Afghanistan  AFG  1993
# Afghanistan  AFG  1994
#
#              Deaths - Liver cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                851
# Afghanistan                                                866
# Afghanistan                                                890
# Afghanistan                                                914
# Afghanistan                                                933
#
#              Deaths - Kidney cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                 66
# Afghanistan                                                 66
# Afghanistan                                                 68
# Afghanistan                                                 70
# Afghanistan                                                 71
#
#              Deaths - Lip and oral cavity cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                 89
# Afghanistan                                                 89
# Afghanistan                                                 91
# Afghanistan                                                 93
# Afghanistan                                                 94
#
#              Deaths - Tracheal, bronchus, and lung cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                983
# Afghanistan                                                982
# Afghanistan                                                989
# Afghanistan                                                995
# Afghanistan                                                996
#
#              Deaths - Larynx cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                260
# Afghanistan                                                263
# Afghanistan                                                268
# Afghanistan                                                275
# Afghanistan                                                282
#
#              Deaths - Gallbladder and biliary tract cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                180
# Afghanistan                                                182
# Afghanistan                                                185
# Afghanistan                                                189
# Afghanistan                                                193
#
#              Deaths - Malignant skin melanoma - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                 47
# Afghanistan                                                 48
# Afghanistan                                                 51
# Afghanistan                                                 53
# Afghanistan                                                 54
#
#              Deaths - Leukemia - Sex: Both - Age: All Ages (Number)  ...  \
# Entity                                                               ...
# Afghanistan                                               1055       ...
# Afghanistan                                               1089       ...
# Afghanistan                                               1171       ...
# Afghanistan                                               1252       ...
# Afghanistan                                               1296       ...
#
#              Deaths - Brain and central nervous system cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                422
# Afghanistan                                                438
# Afghanistan                                                472
# Afghanistan                                                505
# Afghanistan                                                526
#
#              Deaths - Non-Hodgkin lymphoma - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                996
# Afghanistan                                               1010
# Afghanistan                                               1040
# Afghanistan                                               1062
# Afghanistan                                               1069
#
#              Deaths - Pancreatic cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                138
# Afghanistan                                                137
# Afghanistan                                                137
# Afghanistan                                                139
# Afghanistan                                                140
#
#              Deaths - Esophageal cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                529
# Afghanistan                                                535
# Afghanistan                                                546
# Afghanistan                                                560
# Afghanistan                                                575
#
#              Deaths - Testicular cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                  3
# Afghanistan                                                  4
# Afghanistan                                                  4
# Afghanistan                                                  5
# Afghanistan                                                  5
#
#              Deaths - Nasopharynx cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                 66
# Afghanistan                                                 67
# Afghanistan                                                 69
# Afghanistan                                                 72
# Afghanistan                                                 73
#
#              Deaths - Other pharynx cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                 37
# Afghanistan                                                 37
# Afghanistan                                                 38
# Afghanistan                                                 39
# Afghanistan                                                 39
#
#              Deaths - Colon and rectum cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                539
# Afghanistan                                                542
# Afghanistan                                                550
# Afghanistan                                                555
# Afghanistan                                                554
#
#              Deaths - Non-melanoma skin cancer - Sex: Both - Age: All Ages (Number)  \
# Entity
# Afghanistan                                                 25
# Afghanistan                                                 26
# Afghanistan                                                 26
# Afghanistan                                                 27
# Afghanistan                                                 28
#
#              Deaths - Mesothelioma - Sex: Both - Age: All Ages (Number)
# Entity
# Afghanistan                                                  6
# Afghanistan                                                  7
# Afghanistan                                                  7
# Afghanistan                                                  7
# Afghanistan                                                  8
#
# [5 rows x 31 columns]
